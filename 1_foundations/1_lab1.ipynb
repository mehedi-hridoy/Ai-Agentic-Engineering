# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If two trains start from points A and B, 300 miles apart, heading toward each other at speeds of 60 mph and 40 mph respectively, a bird starts flying from the front of the first train toward the second train at 100 mph, immediately turning back upon reaching it, and continues flying back and forth between the two trains until they collide. How far does the bird travel before the trains collide?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the problem step-by-step.
#
# ### Given:
# - Distance between the trains initially: 300 miles
# - Train A speed: 60 mph
# - Train B speed: 40 mph
# - Bird speed: 100 mph
# - The trains move toward each other.
# - The bird flies back and forth between the trains until they collide.
#
# ---
#
# ### Step 1: Determine the time until collision
# The two trains are moving toward each other, so their relative speed is the sum of their speeds:
#
# \[
# v_{\text{relative}} = 60 \text{ mph} + 40 \text{ mph} = 100 \text{ mph}
# \]
#
# Since they start 300 miles apart, the time until they collide is:
#
# \[
# t = \frac{\text{distance}}{\text{relative speed}} = \frac{300 \text{ miles}}{100 \text{ mph}} = 3 \text{ hours}
# \]
#
# ---
#
# ### Step 2: Calculate the total distance the bird flies
# The bird flies continuously at 100 mph for the entire 3 hours until the trains collide.
#
# Therefore,
#
# \[
# \text{distance}_{\text{bird}} = \text{speed}_{\text{bird}} \times \text{time} = 100 \text{ mph} \times 3 \text{ hours} = 300 \text{ miles}
# \]
#
# ---
#
# ### **Final answer:**
#
# \[
# \boxed{300 \text{ miles}}
# \]
#
# The bird travels 300 miles before the trains collide.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's analyze the problem step-by-step.
#
# ### Given:
# - Distance between the trains initially: 300 miles
# - Train A speed: 60 mph
# - Train B speed: 40 mph
# - Bird speed: 100 mph
# - The trains move toward each other.
# - The bird flies back and forth between the trains until they collide.
#
# ---
#
# ### Step 1: Determine the time until collision
# The two trains are moving toward each other, so their relative speed is the sum of their speeds:
#
# \[
# v_{\text{relative}} = 60 \text{ mph} + 40 \text{ mph} = 100 \text{ mph}
# \]
#
# Since they start 300 miles apart, the time until they collide is:
#
# \[
# t = \frac{\text{distance}}{\text{relative speed}} = \frac{300 \text{ miles}}{100 \text{ mph}} = 3 \text{ hours}
# \]
#
# ---
#
# ### Step 2: Calculate the total distance the bird flies
# The bird flies continuously at 100 mph for the entire 3 hours until the trains collide.
#
# Therefore,
#
# \[
# \text{distance}_{\text{bird}} = \text{speed}_{\text{bird}} \times \text{time} = 100 \text{ mph} \times 3 \text{ hours} = 300 \text{ miles}
# \]
#
# ---
#
# ### **Final answer:**
#
# \[
# \boxed{300 \text{ miles}}
# \]
#
# The bird travels 300 miles before the trains collide.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# And now - let's ask for a question:

question = "Pick a business area that might be worth exploring for an Agentic AI Opportunity. Respond only with the area, no explanation."
messages = [{"role": "user", "content": question}]

# %%
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# Healthcare diagnostics

# %%
# working with 2nd question
question = "So now find the pain point in HealthCare diagnostics that an AI Agent could solve, and propose a business idea around it. Something chellenging maybe ripe for Agentic AI."
messages = [{"role": "user", "content": question}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content
print(business_idea)
# Out:
# Certainly! Let’s start by identifying a compelling pain point in healthcare diagnostics that remains challenging and could significantly benefit from an agentic AI approach.
#
# ---
#
# ### Pain Point: Early and Accurate Detection of Rare and Complex Diseases
#
# **Context:**
# Rare and complex diseases (e.g., certain autoimmune conditions, rare cancers, genetic disorders) often face delayed or incorrect diagnosis. This happens because:
#
# - Symptoms are often nonspecific and heterogeneous.
# - Diagnostic tests may require integration across multiple modalities (imaging, labs, genetics, clinical notes).
# - Expertise is fragmented; rare disease specialists are scarce and geographically dispersed.
# - Traditional diagnostic workflows are linear and passive, missing nuanced patterns or requiring extensive manual review.
#
# **Challenges:**
# - Data fragmentation across electronic health records (EHRs), imaging systems (PACS), genomics, and labs.
# - Need for continual hypothesis generation and testing (differential diagnosis).
# - Dynamic patient monitoring to detect subtle disease progression or flare-ups.
# - Collaboration across multidisciplinary teams.
#
# ---
#
# ### Why Agentic AI?
#
# Agentic AI systems can autonomously orchestrate complex workflows, gather and integrate multi-modal data, seek expert guidance when uncertain, and adapt their reasoning based on context. They can:
#
# - Proactively query relevant data sources.
# - Continuously learn from outcomes and feedback.
# - Explain their reasoning to clinicians to enhance trust.
# - Automate hypothesis generation and differential diagnosis steps.
#
# ---
#
# ### Proposed Business Idea: **DiagnoSphere — An Autonomous AI Diagnostic Agent for Rare and Complex Diseases**
#
# ---
#
# #### Product Concept
#
# **DiagnoSphere** is a cloud-based AI agent platform designed for hospitals and specialty clinics that automates and accelerates the diagnostic workflow of rare and complex diseases by:
#
# - **Multi-modal Data Integration:** Automatically integrates patient EHR data, lab results, genomic data, imaging scans, wearable device inputs, and clinical notes using advanced NLP and computer vision.
#
# - **Intelligent Hypothesis Management:** Constructs, tests, and refines diagnostic hypotheses via a continual reasoning engine powered by large language models and symbolic AI.
#
# - **Dynamic Collaboration:** Interfaces with human specialists through a conversational AI interface, providing evidence summaries, requesting expert input, and updating recommendations in real-time.
#
# - **Outcome Feedback Loop:** Monitors treatment outcomes and follow-up data to refine diagnostic models continuously.
#
# ---
#
# #### Key Features
#
# - **Autonomous Case Investigation:** The AI proactively identifies missing information, suggests targeted tests, and schedules follow-up diagnostics.
#
# - **Explainable Recommendations:** Provides transparent diagnostic reasoning trails to support clinician decision-making and improve trust.
#
# - **Rare Disease Training Library:** Continuously updated knowledge base sourced from global medical literature, clinical trial data, and patient registries.
#
# - **Integration APIs:** Seamlessly integrates with hospital IT systems (EHR, PACS, LIS).
#
# ---
#
# #### Market & Opportunity
#
# - Estimated 300 million people worldwide affected by rare diseases — many remain undiagnosed or misdiagnosed.
# - Reduces diagnostic odyssey time from years to months or weeks.
# - Supports specialists in resource-constrained settings.
# - Potential payers: hospitals, specialty diagnostic labs, large healthcare networks, pharmaceutical companies (for better patient stratification in trials).
#
# ---
#
# #### Business Model
#
# - **SaaS Subscription:** Tiered pricing based on usage (number of cases processed) and integrations.
# - **Collaborations with Pharma and Research:** Provide de-identified insights or agent-assisted diagnostics to support rare disease drug development and precision medicine.
# - **Consulting/Customization:** Specialized services to customize AI agents for unique institutional workflows.
#
# ---
#
# ### Why Now?
#
# - Advances in AI (large language models, multimodal learning) now enable complex reasoning across heterogeneous medical data.
# - Growing digitization of health data.
# - Pressing unmet need in rare disease diagnostics.
# - Availability of cloud infrastructure supporting real-time multi-agent orchestration.
#
# ---
#
# ### Summary
#
# **DiagnoSphere** leverages agentic AI’s autonomous reasoning and multi-modal integration strengths to crack one of healthcare’s hardest puzzles: rapidly and reliably diagnosing rare and complex diseases. This ambitious but technically feasible vision offers a dramatically improved diagnostic experience for patients and clinicians alike, unlocking a large and underserved niche in healthcare.
#
# ---
#
# If you want, I can help you draft a detailed go-to-market plan or technical architecture for DiagnoSphere next!

# %%
# working with 2nd question
question = "Now find the agentic solution on health care diagonistic on " + business_idea
messages = [{"role": "user", "content": question}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Then read the business idea:

solution_idea = response.choices[0].message.content
print(solution_idea)
# Out:
# This is a very well thought-out and compelling agentic AI solution to a critical pain point! To build on this, here’s a refined summary and some next steps you might consider to operationalize DiagnoSphere:
#
# ---
#
# ## Refined Executive Summary for DiagnoSphere
#
# **DiagnoSphere** is an autonomous AI diagnostic agent designed to transform the early and accurate detection of rare and complex diseases. By integrating multi-modal patient data (EHR, imaging, genomics, labs, wearables) and employing advanced agentic AI capabilities like autonomous hypothesis generation, continuous learning, and dynamic collaboration with human experts, DiagnoSphere accelerates the diagnostic process while increasing precision and transparency. The solution reduces diagnostic delays that can span years, improving patient outcomes and optimizing specialist resources globally.
#
# ---
#
# ## Next Steps & Recommendations
#
# ### 1. Technical Architecture & Development Roadmap
#
# - **Data Integration Layer:** Develop connectors/APIs for EHRs (HL7, FHIR), PACS, lab systems, genomic databases, wearables, and clinical documents.
# - **Multi-Modal AI Reasoning Engine:** Build the core agent that performs hypothesis generation/testing, leveraging LLMs fine-tuned on medical corpora plus symbolic reasoning for clinical rules.
# - **Explainability Module:** Integrate interpretable AI techniques to create transparent decision paths and evidence summaries.
# - **Collaboration Interface:** Design conversational AI for interactive querying and consultations between AI and clinicians.
# - **Feedback & Learning Loop:** Implement outcome tracking and model updating pipelines using reinforcement learning or active learning methods.
#
# ### 2. Clinical Partnerships & Validation
#
# - Engage with leading rare disease centers and specialty clinics to co-develop and pilot the system.
# - Collect annotated cases and feedback to iteratively improve accuracy.
# - Validate diagnostic improvements through retrospective and prospective clinical studies.
#
# ### 3. Regulatory & Compliance
#
# - Plan early for compliance with healthcare regulations (HIPAA, GDPR, FDA AI/ML guidance).
# - Develop robust data privacy, security, and audit trails as a foundational capability.
#
# ### 4. Go-To-Market & Business Development
#
# - Focus initial pilots on rare disease hotbeds to demonstrate value rapidly.
# - Develop relationships with pharmaceutical firms for co-development and data sharing agreements.
# - Explore reimbursement models linked to diagnostic efficiency and outcomes improvements.
#
# ### 5. Funding & Team
#
# - Seek seed funding or grants specific to AI in healthcare and rare diseases.
# - Assemble an interdisciplinary team: AI scientists, clinical experts, regulatory, and business development leaders.
#
# ---
#
# If you want, I can help draft a more detailed technical architecture diagram, a product requirements document (PRD), or a phased go-to-market plan next. Just let me know!
